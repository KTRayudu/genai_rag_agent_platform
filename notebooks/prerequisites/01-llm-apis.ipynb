# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")
# Out:
# True

# %% [markdown]
# ### OpenAI Client

# %%
import openai

response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ]
)

print(response.choices[0].message.content)

# %%
response.usage

# %%
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="minimal"
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 response = openai.chat.completions.create(
#       2     model="gpt-5-nano",
#       3     messages=[
#       4         {"role": "system", "content": "You are a helpful assistant."},
#       5         {"role": "user", "content": "can you print 10 random words?"}
#       6     ],
#       7     reasoning_effort="minimal"
#       8 )
#      10 print(response.choices[0].message.content)
#
# NameError: name 'openai' is not defined

# %%
response.usage

# %%
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 10 random words?"}
    ],
    reasoning_effort="low"
)

print(response.choices[0].message.content)

# %%
response.usage

# %% [markdown]
# ### Google genai Client

# %%
from google import genai

gemini_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant",
              "can you print 15 random words?"]
)

print(response.text)
# Out:
# Here are 15 random words for you:
#
# 1.  **Enigma**
# 2.  **Luminous**
# 3.  **Ephemeral**
# 4.  **Serendipity**
# 5.  **Quirk**
# 6.  **Benevolent**
# 7.  **Ponder**
# 8.  **Mellifluous**
# 9.  **Zephyr**
# 10. **Ubiquitous**
# 11. **Whimsical**
# 12. **Tranquil**
# 13. **Resilient**
# 14. **Verdant**
# 15. **Capricious**

# %% [markdown]
# ### Groq Client

# %%
from groq import Groq

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "can you print 20 random words?"}
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Here are 20 random words:
#
# 1. Space
# 2. Helicopter
# 3. Cake
# 4. Diamond
# 5. Computer
# 6. Pineapple
# 7. Guitar
# 8. Snowflake
# 9. Perfume
# 10. Bicycle
# 11. Banana
# 12. Violin
# 13. Starfish
# 14. Football
# 15. Harmonica
# 16. Coffee
# 17. Telescope
# 18. Subway
# 19. Butterfly
# 20. Fountain

# %%
import sys
print(sys.executable)
# Out:
# /home/rayudu/otherwork_assignment_all_jobs/Todo/ai_multi_agent_shopping_assistant/.venv/bin/python3

# %%
import sys
print(sys.executable)
# Out:
# /home/rayudu/otherwork_assignment_all_jobs/Todo/ai_multi_agent_shopping_assistant/.venv/bin/python3
